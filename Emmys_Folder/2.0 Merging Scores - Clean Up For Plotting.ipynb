# %% [markdown]
# ### Initial Set up

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import json
import re
from os import path


# Remove dataFrame display size restrictions
pd.set_option("display.max_rows", None, "display.max_columns", None)

import warnings
warnings.filterwarnings("ignore")

#import data with user descriptiomns/review
emmys_df = pd.read_csv('csv/emmys_frequencies.csv')
scores_df = pd.read_csv('csv/final.csv')

# %% [markdown]
# ### Merge + Ad Hoc Clean up

# %%
# Rename columns - Emmys
emmys_df = emmys_df.rename(columns={"Title": "No"})
emmys_df = emmys_df.rename(columns={"Unnamed: 0": "Title"})

# %%
# Rename Rotten Tomatoes column
scores_df = scores_df.rename(columns={"Rotten Tomatoes": "Rotten_Tomatoes"})

# Remove irrelevant columns
scores_df = scores_df[scores_df.columns.difference(['Year', 'Age', 'type', 'Disney+', 'Index', 'Prime Video', 'Hulu', 'Netflix'])] 

# Lowercase all titles to align with emmys_df
scores_df["Title"] = scores_df["Title"].str.lower()

# %%
# Merge emmys with rotten tomato/IMDb scores
df = emmys_df.merge(scores_df, how='left', on='Title')
df = df.drop(85)

# %%
# Convert Rotten Tomatoes column from % to float and make score out of 10 for future plotting
s = df['Rotten_Tomatoes'].str.replace(r'%', r'').astype('float')/100
df['Rotten_Tomatoes']  = pd.to_numeric(df['Rotten_Tomatoes'], errors='coerce').fillna(s)

df['Rotten_Tomatoes'] = df['Rotten_Tomatoes'] * 10

# %%
# Give index name
df.index.name = 'Index'

# %%
# Save csv
df.to_csv("csv/combined_scores.csv")

# %%
df
# Out:
#                                                    Title  No  IMDb  \
# Index
# 0                                        game of thrones  30   NaN
# 1                                                   veep  24   8.3
# 2                               the marvelous mrs maisel  21   NaN
# 3                                    saturday night live  20   8.1
# 4                                        handmaid's tale  20   NaN
# 5                                       better call saul  17   8.7
# 6                                                  ozark  17   8.4
# 7                                              the crown  17   8.7
# 8                                                  barry  15   NaN
# 9                                                  fargo  14   8.9
# 10                                             westworld  14   NaN
# 11                                            this is us  14   8.7
# 12      the people v. o.j. simpson: american crime story  13   NaN
# 13                                            succession  13   NaN
# 14                                               atlanta  13   8.6
# 15                                        silicon valley  12   NaN
# 16                                             black-ish  12   7.1
# 17                                           killing eve  12   8.3
# 18                                        schitt’s creek  11   NaN
# 19                                       stranger things  11   8.8
# 20                                      when they see us  11   8.9
# 21                                              watchmen  11   NaN
# 22                                         the americans  11   8.4
# 23                                        house of cards  10   8.7
# 24                                  feud: bette and joan  10   NaN
# 25                                       big little lies  10   NaN
# 26                                        the good place   9   8.2
# 27                             unbreakable kimmy schmidt   9   7.6
# 28     the assassination of gianni versace: american ...   9   NaN
# 29                                           transparent   8   7.8
# 30                                          the night of   8   NaN
# 31                                        master of none   7   8.3
# 32                                          fosse/verdon   7   7.9
# 33                                              homeland   7   NaN
# 34                    last week tonight with john oliver   7   NaN
# 35                                   escape at dannemora   7   8.0
# 36                                             chernobyl   6   NaN
# 37                                               godless   6   8.3
# 38                        full frontal with samantha bee   6   NaN
# 39                                     the night manager   6   8.1
# 40                                        american crime   6   7.8
# 41                                          black mirror   6   8.8
# 42                    the late show with stephen colbert   6   NaN
# 43                                          mrs. america   6   7.5
# 44                                               fleabag   6   8.7
# 45                                    jimmy kimmel live!   6   6.6
# 46                                      the morning show   5   NaN
# 47                                         drunk history   5   7.8
# 48                                                  glow   5   8.0
# 49                                              top chef   5   7.5
# 50                                   the kominsky method   5   8.2
# 51                                             the voice   5   6.5
# 52                                         modern family   5   8.4
# 53                                             hollywood   4   7.7
# 54                                      the amazing race   4   7.6
# 55                                               baskets   4   7.5
# 56                                              sherlock   4   9.1
# 57                jesus christ superstar live in concert   4   NaN
# 58                                 american horror story   4   8.0
# 59                                           all the way   4   NaN
# 60                                a very english scandal   4   7.7
# 61                                american ninja warrior   4   6.8
# 62                                            dead to me   4   8.1
# 63                                          russian doll   4   7.9
# 64                                       patrick melrose   4   8.1
# 65                  the late late show with james corden   4   NaN
# 66                                         downton abbey   4   8.7
# 67                             what we do in the shadows   4   8.4
# 68                                           ray donovan   4   NaN
# 69                                     grace and frankie   4   8.3
# 70                                            unorthodox   4   8.1
# 71                                     rupauls drag race   4   NaN
# 72                                              insecure   4   NaN
# 73                                          unbelievable   3   8.4
# 74                                             mr. robot   3   8.5
# 75                                                  ramy   3   8.0
# 76                                    the wizard of lies   3   NaN
# 77                                         sharp objects   3   NaN
# 78                                  curb your enthusiasm   3   8.7
# 79                                        project runway   3   7.3
# 80                                                genius   3   8.4
# 81                           how to get away with murder   3   8.1
# 82                               little fires everywhere   3   7.7
# 83                                                   mom   3   7.2
# 84                                             shameless   3   8.6
# 86                                         normal people   3   8.8
# 87                                            portlandia   3   7.8
# 88                                                  pose   3   8.6
# 89                                     the looming tower   3   8.0
# 90                       the daily show with trevor noah   3   NaN
# 91                                          black monday   2   NaN
# 92                                          will & grace   2   7.2
# 93                                  john mulaney special   2   NaN
# 94                       amy schumer: live at the apollo   2   NaN
# 95                                   the big bang theory   2   NaN
# 96                                             bloodline   2   8.0
# 97                                         better things   2   7.7
# 98                                             bodyguard   2   8.1
# 99                                     tracy ullman show   2   NaN
# 100                                   inside amy schumer   2   6.0
# 101                                         confirmation   2   NaN
# 102                             at home with amy sedaris   2   NaN
# 103                                         orphan black   2   8.3
# 104                                            the great   2   7.8
# 105                                     documentary now!   2   8.1
# 106                                           getting on   2   8.1
# 107                                           nailed it!   2   7.4
# 108                                           twin peaks   2   8.8
# 109                                          key & peele   2   8.3
# 110                                   brooklyn nine-nine   2   8.4
# 111                                      genius: picasso   2   NaN
# 112                                               unreal   2   7.8
# 113                            real time with bill maher   2   NaN
# 114                                               luther   2   8.5
# 115    steve martin & martin short: an evening you wi...   2   NaN
# 116                                              the act   2   8.0
# 117                                 my dinner with hervé   1   NaN
# 118                                        the good wife   1   8.3
# 119                      triumph’s election special 2016   1   NaN
# 120                             michelle wolf: nice lady   1   NaN
# 121                              a very murray christmas   1   NaN
# 122                                             the tale   1   NaN
# 123                                        seven seconds   1   7.7
# 124                                      american vandal   1   8.2
# 125                                    the masked singer   1   6.3
# 126                             i know this much is true   1   NaN
# 127                           dave chappelle: equanimity   1   NaN
# 128                               dancing with the stars   1   4.4
# 129                                            self made   1   NaN
# 130                                                 waco   1   7.9
# 131                                            king lear   1   NaN
# 132                                        grease: live!   1   NaN
# 133         law & order true crime: the menendez murders   1   NaN
# 134                                           the affair   1   7.9
# 135                                           the oscars   1   NaN
# 136                                  deadwood: the movie   1   NaN
# 137                            the kennedy center honors   1   NaN
# 138                                             euphoria   1   NaN
# 139    super bowl lii halftime show starring justin t...   1   NaN
# 140                                         the alienist   1   NaN
# 141                                the last man on earth   1   7.3
# 142                                      who is america?   1   NaN
# 143                                     love you america   1   NaN
# 144                                              oseanne   1   NaN
# 145                                             lemonade   1   NaN
# 146                              orange is the new black   1   8.1
# 147                  tig notaro: boyish girl interrupted   1   NaN
# 148                  patton oswalt: talking for clapping   1   NaN
# 149                 the immortal life of henrietta lacks   1   NaN
# 150               the tonight show starring jimmy fallon   1   7.3
# 151                          late night with seth meyers   1   6.1
# 152                                              paterno   1   NaN
# 153              dolly parton’s christmas of many colors   1   NaN
# 154                          adele live in new york city   1   NaN
# 155                                          catastrophe   1   8.2
# 156                                      the mandalorian   1   8.7
# 157                                           the sinner   1   8.0
# 158                                      documentary now   1   NaN
# 159                                               empire   1   7.4
# 160                                               brexit   1   NaN
# 161                                                roots   1   7.9
# 162                     comedians in cars getting coffee   1   8.1
# 163                                       true detective   1   NaN
# 164                                   58th grammy awards   1   NaN
# 165                  lady day at emerson’s bar and grill   1   NaN
# 166                          patton oswalt: annihilation   1   NaN
# 167                                  billy on the street   1   7.7
# 168              i love you america with sarah silverman   1   NaN
# 169                                        bad education   1   7.4
# 170                                                pen15   1   7.9
# 171                                            the knick   1   NaN
# 172                jerry seinfeld: jerry before seinfeld   1   NaN
#
#        Rotten_Tomatoes
# Index
# 0                  NaN
# 1                  9.3
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  9.7
# 6                  8.1
# 7                  8.9
# 8                  NaN
# 9                  9.6
# 10                 NaN
# 11                 9.2
# 12                 NaN
# 13                 NaN
# 14                 9.7
# 15                 NaN
# 16                 9.1
# 17                 9.0
# 18                 NaN
# 19                 9.3
# 20                 9.6
# 21                 NaN
# 22                 9.6
# 23                 7.8
# 24                 NaN
# 25                 NaN
# 26                 9.7
# 27                 9.6
# 28                 NaN
# 29                 9.0
# 30                 NaN
# 31                10.0
# 32                 8.1
# 33                 NaN
# 34                 NaN
# 35                 8.9
# 36                 NaN
# 37                 8.5
# 38                 NaN
# 39                 9.1
# 40                 9.7
# 41                 8.3
# 42                 NaN
# 43                 9.6
# 44                10.0
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 9.3
# 49                 NaN
# 50                 9.0
# 51                 NaN
# 52                 8.6
# 53                 5.7
# 54                 NaN
# 55                 9.2
# 56                 7.8
# 57                 NaN
# 58                 NaN
# 59                 NaN
# 60                 9.5
# 61                 NaN
# 62                 9.1
# 63                 9.6
# 64                 9.0
# 65                 NaN
# 66                 NaN
# 67                 9.7
# 68                 NaN
# 69                 8.9
# 70                 9.4
# 71                 NaN
# 72                 NaN
# 73                 9.7
# 74                 9.4
# 75                 9.7
# 76                 NaN
# 77                 NaN
# 78                 9.2
# 79                 NaN
# 80                 7.0
# 81                 8.8
# 82                 7.7
# 83                 NaN
# 84                 8.5
# 86                 8.3
# 87                 9.4
# 88                 9.6
# 89                 8.8
# 90                 NaN
# 91                 NaN
# 92                 NaN
# 93                 NaN
# 94                 NaN
# 95                 NaN
# 96                 6.2
# 97                 9.7
# 98                 9.3
# 99                 NaN
# 100                8.6
# 101                NaN
# 102                NaN
# 103                9.3
# 104                8.1
# 105                9.4
# 106                NaN
# 107                9.8
# 108                8.9
# 109                9.7
# 110                9.7
# 111                NaN
# 112                8.2
# 113                NaN
# 114                8.8
# 115                NaN
# 116                8.9
# 117                NaN
# 118                9.4
# 119                NaN
# 120                NaN
# 121                NaN
# 122                NaN
# 123                7.7
# 124                9.7
# 125                NaN
# 126                NaN
# 127                NaN
# 128                NaN
# 129                NaN
# 130                6.8
# 131                NaN
# 132                NaN
# 133                NaN
# 134                8.6
# 135                NaN
# 136                NaN
# 137                NaN
# 138                NaN
# 139                NaN
# 140                NaN
# 141                8.4
# 142                NaN
# 143                NaN
# 144                NaN
# 145                NaN
# 146                9.0
# 147                NaN
# 148                NaN
# 149                NaN
# 150                NaN
# 151                NaN
# 152                NaN
# 153                NaN
# 154                NaN
# 155                9.8
# 156                9.3
# 157                9.5
# 158                NaN
# 159                8.4
# 160                NaN
# 161                9.6
# 162                NaN
# 163                NaN
# 164                NaN
# 165                NaN
# 166                NaN
# 167                NaN
# 168                NaN
# 169                NaN
# 170                9.3
# 171                NaN
# 172                NaN

# %% [markdown]
# ### Convert to JSON Array for Future Plotting

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = [] 
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary 
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['Index']
            data.append(rows)
 
    # Open a json writer, and use the json.dumps() 
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Create two file paths
csvFilePath = r'csv/combined_scores.csv'
jsonFilePath = r'plot_scores/scores_array.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
df
# Out:
#                                                    Title  No  IMDb  \
# Index
# 0                                        game of thrones  30   NaN
# 1                                                   veep  24   8.3
# 2                               the marvelous mrs maisel  21   NaN
# 3                                    saturday night live  20   8.1
# 4                                        handmaid's tale  20   NaN
# 5                                       better call saul  17   8.7
# 6                                                  ozark  17   8.4
# 7                                              the crown  17   8.7
# 8                                                  barry  15   NaN
# 9                                                  fargo  14   8.9
# 10                                             westworld  14   NaN
# 11                                            this is us  14   8.7
# 12      the people v. o.j. simpson: american crime story  13   NaN
# 13                                            succession  13   NaN
# 14                                               atlanta  13   8.6
# 15                                        silicon valley  12   NaN
# 16                                             black-ish  12   7.1
# 17                                           killing eve  12   8.3
# 18                                        schitt’s creek  11   NaN
# 19                                       stranger things  11   8.8
# 20                                      when they see us  11   8.9
# 21                                              watchmen  11   NaN
# 22                                         the americans  11   8.4
# 23                                        house of cards  10   8.7
# 24                                  feud: bette and joan  10   NaN
# 25                                       big little lies  10   NaN
# 26                                        the good place   9   8.2
# 27                             unbreakable kimmy schmidt   9   7.6
# 28     the assassination of gianni versace: american ...   9   NaN
# 29                                           transparent   8   7.8
# 30                                          the night of   8   NaN
# 31                                        master of none   7   8.3
# 32                                          fosse/verdon   7   7.9
# 33                                              homeland   7   NaN
# 34                    last week tonight with john oliver   7   NaN
# 35                                   escape at dannemora   7   8.0
# 36                                             chernobyl   6   NaN
# 37                                               godless   6   8.3
# 38                        full frontal with samantha bee   6   NaN
# 39                                     the night manager   6   8.1
# 40                                        american crime   6   7.8
# 41                                          black mirror   6   8.8
# 42                    the late show with stephen colbert   6   NaN
# 43                                          mrs. america   6   7.5
# 44                                               fleabag   6   8.7
# 45                                    jimmy kimmel live!   6   6.6
# 46                                      the morning show   5   NaN
# 47                                         drunk history   5   7.8
# 48                                                  glow   5   8.0
# 49                                              top chef   5   7.5
# 50                                   the kominsky method   5   8.2
# 51                                             the voice   5   6.5
# 52                                         modern family   5   8.4
# 53                                             hollywood   4   7.7
# 54                                      the amazing race   4   7.6
# 55                                               baskets   4   7.5
# 56                                              sherlock   4   9.1
# 57                jesus christ superstar live in concert   4   NaN
# 58                                 american horror story   4   8.0
# 59                                           all the way   4   NaN
# 60                                a very english scandal   4   7.7
# 61                                american ninja warrior   4   6.8
# 62                                            dead to me   4   8.1
# 63                                          russian doll   4   7.9
# 64                                       patrick melrose   4   8.1
# 65                  the late late show with james corden   4   NaN
# 66                                         downton abbey   4   8.7
# 67                             what we do in the shadows   4   8.4
# 68                                           ray donovan   4   NaN
# 69                                     grace and frankie   4   8.3
# 70                                            unorthodox   4   8.1
# 71                                     rupauls drag race   4   NaN
# 72                                              insecure   4   NaN
# 73                                          unbelievable   3   8.4
# 74                                             mr. robot   3   8.5
# 75                                                  ramy   3   8.0
# 76                                    the wizard of lies   3   NaN
# 77                                         sharp objects   3   NaN
# 78                                  curb your enthusiasm   3   8.7
# 79                                        project runway   3   7.3
# 80                                                genius   3   8.4
# 81                           how to get away with murder   3   8.1
# 82                               little fires everywhere   3   7.7
# 83                                                   mom   3   7.2
# 84                                             shameless   3   8.6
# 86                                         normal people   3   8.8
# 87                                            portlandia   3   7.8
# 88                                                  pose   3   8.6
# 89                                     the looming tower   3   8.0
# 90                       the daily show with trevor noah   3   NaN
# 91                                          black monday   2   NaN
# 92                                          will & grace   2   7.2
# 93                                  john mulaney special   2   NaN
# 94                       amy schumer: live at the apollo   2   NaN
# 95                                   the big bang theory   2   NaN
# 96                                             bloodline   2   8.0
# 97                                         better things   2   7.7
# 98                                             bodyguard   2   8.1
# 99                                     tracy ullman show   2   NaN
# 100                                   inside amy schumer   2   6.0
# 101                                         confirmation   2   NaN
# 102                             at home with amy sedaris   2   NaN
# 103                                         orphan black   2   8.3
# 104                                            the great   2   7.8
# 105                                     documentary now!   2   8.1
# 106                                           getting on   2   8.1
# 107                                           nailed it!   2   7.4
# 108                                           twin peaks   2   8.8
# 109                                          key & peele   2   8.3
# 110                                   brooklyn nine-nine   2   8.4
# 111                                      genius: picasso   2   NaN
# 112                                               unreal   2   7.8
# 113                            real time with bill maher   2   NaN
# 114                                               luther   2   8.5
# 115    steve martin & martin short: an evening you wi...   2   NaN
# 116                                              the act   2   8.0
# 117                                 my dinner with hervé   1   NaN
# 118                                        the good wife   1   8.3
# 119                      triumph’s election special 2016   1   NaN
# 120                             michelle wolf: nice lady   1   NaN
# 121                              a very murray christmas   1   NaN
# 122                                             the tale   1   NaN
# 123                                        seven seconds   1   7.7
# 124                                      american vandal   1   8.2
# 125                                    the masked singer   1   6.3
# 126                             i know this much is true   1   NaN
# 127                           dave chappelle: equanimity   1   NaN
# 128                               dancing with the stars   1   4.4
# 129                                            self made   1   NaN
# 130                                                 waco   1   7.9
# 131                                            king lear   1   NaN
# 132                                        grease: live!   1   NaN
# 133         law & order true crime: the menendez murders   1   NaN
# 134                                           the affair   1   7.9
# 135                                           the oscars   1   NaN
# 136                                  deadwood: the movie   1   NaN
# 137                            the kennedy center honors   1   NaN
# 138                                             euphoria   1   NaN
# 139    super bowl lii halftime show starring justin t...   1   NaN
# 140                                         the alienist   1   NaN
# 141                                the last man on earth   1   7.3
# 142                                      who is america?   1   NaN
# 143                                     love you america   1   NaN
# 144                                              oseanne   1   NaN
# 145                                             lemonade   1   NaN
# 146                              orange is the new black   1   8.1
# 147                  tig notaro: boyish girl interrupted   1   NaN
# 148                  patton oswalt: talking for clapping   1   NaN
# 149                 the immortal life of henrietta lacks   1   NaN
# 150               the tonight show starring jimmy fallon   1   7.3
# 151                          late night with seth meyers   1   6.1
# 152                                              paterno   1   NaN
# 153              dolly parton’s christmas of many colors   1   NaN
# 154                          adele live in new york city   1   NaN
# 155                                          catastrophe   1   8.2
# 156                                      the mandalorian   1   8.7
# 157                                           the sinner   1   8.0
# 158                                      documentary now   1   NaN
# 159                                               empire   1   7.4
# 160                                               brexit   1   NaN
# 161                                                roots   1   7.9
# 162                     comedians in cars getting coffee   1   8.1
# 163                                       true detective   1   NaN
# 164                                   58th grammy awards   1   NaN
# 165                  lady day at emerson’s bar and grill   1   NaN
# 166                          patton oswalt: annihilation   1   NaN
# 167                                  billy on the street   1   7.7
# 168              i love you america with sarah silverman   1   NaN
# 169                                        bad education   1   7.4
# 170                                                pen15   1   7.9
# 171                                            the knick   1   NaN
# 172                jerry seinfeld: jerry before seinfeld   1   NaN
#
#        Rotten_Tomatoes
# Index
# 0                  NaN
# 1                  9.3
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  9.7
# 6                  8.1
# 7                  8.9
# 8                  NaN
# 9                  9.6
# 10                 NaN
# 11                 9.2
# 12                 NaN
# 13                 NaN
# 14                 9.7
# 15                 NaN
# 16                 9.1
# 17                 9.0
# 18                 NaN
# 19                 9.3
# 20                 9.6
# 21                 NaN
# 22                 9.6
# 23                 7.8
# 24                 NaN
# 25                 NaN
# 26                 9.7
# 27                 9.6
# 28                 NaN
# 29                 9.0
# 30                 NaN
# 31                10.0
# 32                 8.1
# 33                 NaN
# 34                 NaN
# 35                 8.9
# 36                 NaN
# 37                 8.5
# 38                 NaN
# 39                 9.1
# 40                 9.7
# 41                 8.3
# 42                 NaN
# 43                 9.6
# 44                10.0
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 9.3
# 49                 NaN
# 50                 9.0
# 51                 NaN
# 52                 8.6
# 53                 5.7
# 54                 NaN
# 55                 9.2
# 56                 7.8
# 57                 NaN
# 58                 NaN
# 59                 NaN
# 60                 9.5
# 61                 NaN
# 62                 9.1
# 63                 9.6
# 64                 9.0
# 65                 NaN
# 66                 NaN
# 67                 9.7
# 68                 NaN
# 69                 8.9
# 70                 9.4
# 71                 NaN
# 72                 NaN
# 73                 9.7
# 74                 9.4
# 75                 9.7
# 76                 NaN
# 77                 NaN
# 78                 9.2
# 79                 NaN
# 80                 7.0
# 81                 8.8
# 82                 7.7
# 83                 NaN
# 84                 8.5
# 86                 8.3
# 87                 9.4
# 88                 9.6
# 89                 8.8
# 90                 NaN
# 91                 NaN
# 92                 NaN
# 93                 NaN
# 94                 NaN
# 95                 NaN
# 96                 6.2
# 97                 9.7
# 98                 9.3
# 99                 NaN
# 100                8.6
# 101                NaN
# 102                NaN
# 103                9.3
# 104                8.1
# 105                9.4
# 106                NaN
# 107                9.8
# 108                8.9
# 109                9.7
# 110                9.7
# 111                NaN
# 112                8.2
# 113                NaN
# 114                8.8
# 115                NaN
# 116                8.9
# 117                NaN
# 118                9.4
# 119                NaN
# 120                NaN
# 121                NaN
# 122                NaN
# 123                7.7
# 124                9.7
# 125                NaN
# 126                NaN
# 127                NaN
# 128                NaN
# 129                NaN
# 130                6.8
# 131                NaN
# 132                NaN
# 133                NaN
# 134                8.6
# 135                NaN
# 136                NaN
# 137                NaN
# 138                NaN
# 139                NaN
# 140                NaN
# 141                8.4
# 142                NaN
# 143                NaN
# 144                NaN
# 145                NaN
# 146                9.0
# 147                NaN
# 148                NaN
# 149                NaN
# 150                NaN
# 151                NaN
# 152                NaN
# 153                NaN
# 154                NaN
# 155                9.8
# 156                9.3
# 157                9.5
# 158                NaN
# 159                8.4
# 160                NaN
# 161                9.6
# 162                NaN
# 163                NaN
# 164                NaN
# 165                NaN
# 166                NaN
# 167                NaN
# 168                NaN
# 169                NaN
# 170                9.3
# 171                NaN
# 172                NaN
