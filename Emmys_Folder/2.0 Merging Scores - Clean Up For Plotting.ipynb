# %% [markdown]
# ### Initial Set up

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import json
import re
from os import path


# Remove dataFrame display size restrictions
pd.set_option("display.max_rows", None, "display.max_columns", None)

import warnings
warnings.filterwarnings("ignore")

#import data with user descriptiomns/review
emmys_df = pd.read_csv('csv/emmys_frequencies.csv')
scores_df = pd.read_csv('csv/final.csv')

# %% [markdown]
# ### Merge + Ad Hoc Clean up

# %%
# Rename columns - Emmys
emmys_df = emmys_df.rename(columns={"Title": "No"})
emmys_df = emmys_df.rename(columns={"Unnamed: 0": "Title"})

# %%
# Rename Rotten Tomatoes column
scores_df = scores_df.rename(columns={"Rotten Tomatoes": "Rotten_Tomatoes"})

# Remove irrelevant columns
scores_df = scores_df[scores_df.columns.difference(['Year', 'Age', 'type', 'Disney+', 'Index', 'Prime Video', 'Hulu', 'Netflix'])] 

# Lowercase all titles to align with emmys_df
scores_df["Title"] = scores_df["Title"].str.lower()

# %%
# Merge emmys with rotten tomato/IMDb scores
df = emmys_df.merge(scores_df, how='left', on='Title')
df = df.drop(85)

# %%
# Convert Rotten Tomatoes column from % to float and make score out of 10 for future plotting
s = df['Rotten_Tomatoes'].str.replace(r'%', r'').astype('float')/100
df['Rotten_Tomatoes']  = pd.to_numeric(df['Rotten_Tomatoes'], errors='coerce').fillna(s)

df['Rotten_Tomatoes'] = df['Rotten_Tomatoes'] * 10

# %%
# Give index name
df.index.name = 'Index'

# %%
# Save csv
df.to_csv("csv/combined_scores.csv")

# %%
df
# Out:
#                                                    Title  No  IMDb  \
# Index
# 0                                        game of thrones  30   NaN
# 1                                                   veep  24   8.3
# 2                               the marvelous mrs maisel  21   NaN
# 3                                        handmaid's tale  20   NaN
# 4                                    saturday night live  20   8.1
# 5                                       better call saul  17   8.7
# 6                                              the crown  17   8.7
# 7                                                  ozark  17   8.4
# 8                                                  barry  15   NaN
# 9                                                  fargo  14   8.9
# 10                                            this is us  14   8.7
# 11                                             westworld  14   NaN
# 12                                            succession  13   NaN
# 13                                               atlanta  13   8.6
# 14      the people v. o.j. simpson: american crime story  13   NaN
# 15                                             black-ish  12   7.1
# 16                                           killing eve  12   8.3
# 17                                        silicon valley  12   NaN
# 18                                              watchmen  11   NaN
# 19                                         the americans  11   8.4
# 20                                        schitt’s creek  11   NaN
# 21                                      when they see us  11   8.9
# 22                                       stranger things  11   8.8
# 23                                        house of cards  10   8.7
# 24                                  feud: bette and joan  10   NaN
# 25                                       big little lies  10   NaN
# 26                                        the good place   9   8.2
# 27                             unbreakable kimmy schmidt   9   7.6
# 28     the assassination of gianni versace: american ...   9   NaN
# 29                                          the night of   8   NaN
# 30                                           transparent   8   7.8
# 31                                          fosse/verdon   7   7.9
# 32                                        master of none   7   8.3
# 33                                              homeland   7   NaN
# 34                    last week tonight with john oliver   7   NaN
# 35                                   escape at dannemora   7   8.0
# 36                                     the night manager   6   8.1
# 37                                          mrs. america   6   7.5
# 38                    the late show with stephen colbert   6   NaN
# 39                                    jimmy kimmel live!   6   6.6
# 40                                          black mirror   6   8.8
# 41                                        american crime   6   7.8
# 42                                               godless   6   8.3
# 43                                             chernobyl   6   NaN
# 44                        full frontal with samantha bee   6   NaN
# 45                                               fleabag   6   8.7
# 46                                         drunk history   5   7.8
# 47                                         modern family   5   8.4
# 48                                              top chef   5   7.5
# 49                                      the morning show   5   NaN
# 50                                   the kominsky method   5   8.2
# 51                                                  glow   5   8.0
# 52                                             the voice   5   6.5
# 53                                          russian doll   4   7.9
# 54                                     grace and frankie   4   8.3
# 55                                           all the way   4   NaN
# 56                                           ray donovan   4   NaN
# 57                jesus christ superstar live in concert   4   NaN
# 58                                         downton abbey   4   8.7
# 59                                     rupauls drag race   4   NaN
# 60                             what we do in the shadows   4   8.4
# 61                                      the amazing race   4   7.6
# 62                                            dead to me   4   8.1
# 63                                 american horror story   4   8.0
# 64                                             hollywood   4   7.7
# 65                                              sherlock   4   9.1
# 66                                            unorthodox   4   8.1
# 67                                a very english scandal   4   7.7
# 68                                              insecure   4   NaN
# 69                                american ninja warrior   4   6.8
# 70                                       patrick melrose   4   8.1
# 71                                               baskets   4   7.5
# 72                  the late late show with james corden   4   NaN
# 73                                          unbelievable   3   8.4
# 74                               little fires everywhere   3   7.7
# 75                                            portlandia   3   7.8
# 76                                                   mom   3   7.2
# 77                                                  pose   3   8.6
# 78                                         normal people   3   8.8
# 79                                             mr. robot   3   8.5
# 80                                     the looming tower   3   8.0
# 81                           how to get away with murder   3   8.1
# 82                       the daily show with trevor noah   3   NaN
# 83                                                  ramy   3   8.0
# 84                                        project runway   3   7.3
# 86                                             shameless   3   8.6
# 87                                             shameless   3   8.0
# 88                                         sharp objects   3   NaN
# 89                                                genius   3   8.4
# 90                                    the wizard of lies   3   NaN
# 91                                   the big bang theory   2   NaN
# 92                                             bodyguard   2   8.1
# 93                                           key & peele   2   8.3
# 94                                          will & grace   2   7.2
# 95                                       genius: picasso   2   NaN
# 96                                                luther   2   8.5
# 97                                            nailed it!   2   7.4
# 98                             real time with bill maher   2   NaN
# 99                                             the great   2   7.8
# 100                             at home with amy sedaris   2   NaN
# 101                                         orphan black   2   8.3
# 102                      amy schumer: live at the apollo   2   NaN
# 103                                           twin peaks   2   8.8
# 104                                              the act   2   8.0
# 105                                           getting on   2   8.1
# 106                                               unreal   2   7.8
# 107                                 john mulaney special   2   NaN
# 108                                     documentary now!   2   8.1
# 109                                        better things   2   7.7
# 110                                         black monday   2   NaN
# 111                                            bloodline   2   8.0
# 112                                    tracy ullman show   2   NaN
# 113                                   brooklyn nine-nine   2   8.4
# 114                                   inside amy schumer   2   6.0
# 115                                         confirmation   2   NaN
# 116    steve martin & martin short: an evening you wi...   2   NaN
# 117                                           the sinner   1   8.0
# 118                                          catastrophe   1   8.2
# 119                                        the good wife   1   8.3
# 120                            the kennedy center honors   1   NaN
# 121                                              paterno   1   NaN
# 122                              orange is the new black   1   8.1
# 123                                                roots   1   7.9
# 124                                               empire   1   7.4
# 125                                             the tale   1   NaN
# 126                  patton oswalt: talking for clapping   1   NaN
# 127                      triumph’s election special 2016   1   NaN
# 128                                             euphoria   1   NaN
# 129                             i know this much is true   1   NaN
# 130                                           the affair   1   7.9
# 131                                                 waco   1   7.9
# 132                                            the knick   1   NaN
# 133                                  billy on the street   1   7.7
# 134                jerry seinfeld: jerry before seinfeld   1   NaN
# 135                                                pen15   1   7.9
# 136              i love you america with sarah silverman   1   NaN
# 137                 the immortal life of henrietta lacks   1   NaN
# 138                                       true detective   1   NaN
# 139                                           the oscars   1   NaN
# 140                                      documentary now   1   NaN
# 141                                      who is america?   1   NaN
# 142               the tonight show starring jimmy fallon   1   7.3
# 143                                   58th grammy awards   1   NaN
# 144                                    the masked singer   1   6.3
# 145                          late night with seth meyers   1   6.1
# 146                                      american vandal   1   8.2
# 147                                             lemonade   1   NaN
# 148                                            self made   1   NaN
# 149                  tig notaro: boyish girl interrupted   1   NaN
# 150                                  deadwood: the movie   1   NaN
# 151                                        seven seconds   1   7.7
# 152              dolly parton’s christmas of many colors   1   NaN
# 153                  lady day at emerson’s bar and grill   1   NaN
# 154                     comedians in cars getting coffee   1   8.1
# 155                                        grease: live!   1   NaN
# 156                                        bad education   1   7.4
# 157                          patton oswalt: annihilation   1   NaN
# 158                                      the mandalorian   1   8.7
# 159                               dancing with the stars   1   4.4
# 160                              a very murray christmas   1   NaN
# 161                                         the alienist   1   NaN
# 162                                     love you america   1   NaN
# 163                             michelle wolf: nice lady   1   NaN
# 164                                              oseanne   1   NaN
# 165                                 my dinner with hervé   1   NaN
# 166                                the last man on earth   1   7.3
# 167                                            king lear   1   NaN
# 168                           dave chappelle: equanimity   1   NaN
# 169    super bowl lii halftime show starring justin t...   1   NaN
# 170         law & order true crime: the menendez murders   1   NaN
# 171                                               brexit   1   NaN
# 172                          adele live in new york city   1   NaN
#
#        Rotten_Tomatoes
# Index
# 0                  NaN
# 1                  9.3
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  9.7
# 6                  8.9
# 7                  8.1
# 8                  NaN
# 9                  9.6
# 10                 9.2
# 11                 NaN
# 12                 NaN
# 13                 9.7
# 14                 NaN
# 15                 9.1
# 16                 9.0
# 17                 NaN
# 18                 NaN
# 19                 9.6
# 20                 NaN
# 21                 9.6
# 22                 9.3
# 23                 7.8
# 24                 NaN
# 25                 NaN
# 26                 9.7
# 27                 9.6
# 28                 NaN
# 29                 NaN
# 30                 9.0
# 31                 8.1
# 32                10.0
# 33                 NaN
# 34                 NaN
# 35                 8.9
# 36                 9.1
# 37                 9.6
# 38                 NaN
# 39                 NaN
# 40                 8.3
# 41                 9.7
# 42                 8.5
# 43                 NaN
# 44                 NaN
# 45                10.0
# 46                 NaN
# 47                 8.6
# 48                 NaN
# 49                 NaN
# 50                 9.0
# 51                 9.3
# 52                 NaN
# 53                 9.6
# 54                 8.9
# 55                 NaN
# 56                 NaN
# 57                 NaN
# 58                 NaN
# 59                 NaN
# 60                 9.7
# 61                 NaN
# 62                 9.1
# 63                 NaN
# 64                 5.7
# 65                 7.8
# 66                 9.4
# 67                 9.5
# 68                 NaN
# 69                 NaN
# 70                 9.0
# 71                 9.2
# 72                 NaN
# 73                 9.7
# 74                 7.7
# 75                 9.4
# 76                 NaN
# 77                 9.6
# 78                 8.3
# 79                 9.4
# 80                 8.8
# 81                 8.8
# 82                 NaN
# 83                 9.7
# 84                 NaN
# 86                 8.5
# 87                 NaN
# 88                 NaN
# 89                 7.0
# 90                 NaN
# 91                 NaN
# 92                 9.3
# 93                 9.7
# 94                 NaN
# 95                 NaN
# 96                 8.8
# 97                 9.8
# 98                 NaN
# 99                 8.1
# 100                NaN
# 101                9.3
# 102                NaN
# 103                8.9
# 104                8.9
# 105                NaN
# 106                8.2
# 107                NaN
# 108                9.4
# 109                9.7
# 110                NaN
# 111                6.2
# 112                NaN
# 113                9.7
# 114                8.6
# 115                NaN
# 116                NaN
# 117                9.5
# 118                9.8
# 119                9.4
# 120                NaN
# 121                NaN
# 122                9.0
# 123                9.6
# 124                8.4
# 125                NaN
# 126                NaN
# 127                NaN
# 128                NaN
# 129                NaN
# 130                8.6
# 131                6.8
# 132                NaN
# 133                NaN
# 134                NaN
# 135                9.3
# 136                NaN
# 137                NaN
# 138                NaN
# 139                NaN
# 140                NaN
# 141                NaN
# 142                NaN
# 143                NaN
# 144                NaN
# 145                NaN
# 146                9.7
# 147                NaN
# 148                NaN
# 149                NaN
# 150                NaN
# 151                7.7
# 152                NaN
# 153                NaN
# 154                NaN
# 155                NaN
# 156                NaN
# 157                NaN
# 158                9.3
# 159                NaN
# 160                NaN
# 161                NaN
# 162                NaN
# 163                NaN
# 164                NaN
# 165                NaN
# 166                8.4
# 167                NaN
# 168                NaN
# 169                NaN
# 170                NaN
# 171                NaN
# 172                NaN

# %% [markdown]
# ### Convert to JSON Array for Future Plotting

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = [] 
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary 
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['Index']
            data.append(rows)
 
    # Open a json writer, and use the json.dumps() 
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))
         
# Driver Code
 
# Create two file paths
csvFilePath = r'csv/combined_scores.csv'
jsonFilePath = r'plot_scores/scores_array.json'
 
# Call the make_json function
make_json(csvFilePath, jsonFilePath)

# %%
df
# Out:
#                                                    Title  No  IMDb  \
# Index
# 0                                        game of thrones  30   NaN
# 1                                                   veep  24   8.3
# 2                               the marvelous mrs maisel  21   NaN
# 3                                        handmaid's tale  20   NaN
# 4                                    saturday night live  20   8.1
# 5                                       better call saul  17   8.7
# 6                                              the crown  17   8.7
# 7                                                  ozark  17   8.4
# 8                                                  barry  15   NaN
# 9                                                  fargo  14   8.9
# 10                                            this is us  14   8.7
# 11                                             westworld  14   NaN
# 12                                            succession  13   NaN
# 13                                               atlanta  13   8.6
# 14      the people v. o.j. simpson: american crime story  13   NaN
# 15                                             black-ish  12   7.1
# 16                                           killing eve  12   8.3
# 17                                        silicon valley  12   NaN
# 18                                              watchmen  11   NaN
# 19                                         the americans  11   8.4
# 20                                        schitt’s creek  11   NaN
# 21                                      when they see us  11   8.9
# 22                                       stranger things  11   8.8
# 23                                        house of cards  10   8.7
# 24                                  feud: bette and joan  10   NaN
# 25                                       big little lies  10   NaN
# 26                                        the good place   9   8.2
# 27                             unbreakable kimmy schmidt   9   7.6
# 28     the assassination of gianni versace: american ...   9   NaN
# 29                                          the night of   8   NaN
# 30                                           transparent   8   7.8
# 31                                          fosse/verdon   7   7.9
# 32                                        master of none   7   8.3
# 33                                              homeland   7   NaN
# 34                    last week tonight with john oliver   7   NaN
# 35                                   escape at dannemora   7   8.0
# 36                                     the night manager   6   8.1
# 37                                          mrs. america   6   7.5
# 38                    the late show with stephen colbert   6   NaN
# 39                                    jimmy kimmel live!   6   6.6
# 40                                          black mirror   6   8.8
# 41                                        american crime   6   7.8
# 42                                               godless   6   8.3
# 43                                             chernobyl   6   NaN
# 44                        full frontal with samantha bee   6   NaN
# 45                                               fleabag   6   8.7
# 46                                         drunk history   5   7.8
# 47                                         modern family   5   8.4
# 48                                              top chef   5   7.5
# 49                                      the morning show   5   NaN
# 50                                   the kominsky method   5   8.2
# 51                                                  glow   5   8.0
# 52                                             the voice   5   6.5
# 53                                          russian doll   4   7.9
# 54                                     grace and frankie   4   8.3
# 55                                           all the way   4   NaN
# 56                                           ray donovan   4   NaN
# 57                jesus christ superstar live in concert   4   NaN
# 58                                         downton abbey   4   8.7
# 59                                     rupauls drag race   4   NaN
# 60                             what we do in the shadows   4   8.4
# 61                                      the amazing race   4   7.6
# 62                                            dead to me   4   8.1
# 63                                 american horror story   4   8.0
# 64                                             hollywood   4   7.7
# 65                                              sherlock   4   9.1
# 66                                            unorthodox   4   8.1
# 67                                a very english scandal   4   7.7
# 68                                              insecure   4   NaN
# 69                                american ninja warrior   4   6.8
# 70                                       patrick melrose   4   8.1
# 71                                               baskets   4   7.5
# 72                  the late late show with james corden   4   NaN
# 73                                          unbelievable   3   8.4
# 74                               little fires everywhere   3   7.7
# 75                                            portlandia   3   7.8
# 76                                                   mom   3   7.2
# 77                                                  pose   3   8.6
# 78                                         normal people   3   8.8
# 79                                             mr. robot   3   8.5
# 80                                     the looming tower   3   8.0
# 81                           how to get away with murder   3   8.1
# 82                       the daily show with trevor noah   3   NaN
# 83                                                  ramy   3   8.0
# 84                                        project runway   3   7.3
# 86                                             shameless   3   8.6
# 87                                             shameless   3   8.0
# 88                                         sharp objects   3   NaN
# 89                                                genius   3   8.4
# 90                                    the wizard of lies   3   NaN
# 91                                   the big bang theory   2   NaN
# 92                                             bodyguard   2   8.1
# 93                                           key & peele   2   8.3
# 94                                          will & grace   2   7.2
# 95                                       genius: picasso   2   NaN
# 96                                                luther   2   8.5
# 97                                            nailed it!   2   7.4
# 98                             real time with bill maher   2   NaN
# 99                                             the great   2   7.8
# 100                             at home with amy sedaris   2   NaN
# 101                                         orphan black   2   8.3
# 102                      amy schumer: live at the apollo   2   NaN
# 103                                           twin peaks   2   8.8
# 104                                              the act   2   8.0
# 105                                           getting on   2   8.1
# 106                                               unreal   2   7.8
# 107                                 john mulaney special   2   NaN
# 108                                     documentary now!   2   8.1
# 109                                        better things   2   7.7
# 110                                         black monday   2   NaN
# 111                                            bloodline   2   8.0
# 112                                    tracy ullman show   2   NaN
# 113                                   brooklyn nine-nine   2   8.4
# 114                                   inside amy schumer   2   6.0
# 115                                         confirmation   2   NaN
# 116    steve martin & martin short: an evening you wi...   2   NaN
# 117                                           the sinner   1   8.0
# 118                                          catastrophe   1   8.2
# 119                                        the good wife   1   8.3
# 120                            the kennedy center honors   1   NaN
# 121                                              paterno   1   NaN
# 122                              orange is the new black   1   8.1
# 123                                                roots   1   7.9
# 124                                               empire   1   7.4
# 125                                             the tale   1   NaN
# 126                  patton oswalt: talking for clapping   1   NaN
# 127                      triumph’s election special 2016   1   NaN
# 128                                             euphoria   1   NaN
# 129                             i know this much is true   1   NaN
# 130                                           the affair   1   7.9
# 131                                                 waco   1   7.9
# 132                                            the knick   1   NaN
# 133                                  billy on the street   1   7.7
# 134                jerry seinfeld: jerry before seinfeld   1   NaN
# 135                                                pen15   1   7.9
# 136              i love you america with sarah silverman   1   NaN
# 137                 the immortal life of henrietta lacks   1   NaN
# 138                                       true detective   1   NaN
# 139                                           the oscars   1   NaN
# 140                                      documentary now   1   NaN
# 141                                      who is america?   1   NaN
# 142               the tonight show starring jimmy fallon   1   7.3
# 143                                   58th grammy awards   1   NaN
# 144                                    the masked singer   1   6.3
# 145                          late night with seth meyers   1   6.1
# 146                                      american vandal   1   8.2
# 147                                             lemonade   1   NaN
# 148                                            self made   1   NaN
# 149                  tig notaro: boyish girl interrupted   1   NaN
# 150                                  deadwood: the movie   1   NaN
# 151                                        seven seconds   1   7.7
# 152              dolly parton’s christmas of many colors   1   NaN
# 153                  lady day at emerson’s bar and grill   1   NaN
# 154                     comedians in cars getting coffee   1   8.1
# 155                                        grease: live!   1   NaN
# 156                                        bad education   1   7.4
# 157                          patton oswalt: annihilation   1   NaN
# 158                                      the mandalorian   1   8.7
# 159                               dancing with the stars   1   4.4
# 160                              a very murray christmas   1   NaN
# 161                                         the alienist   1   NaN
# 162                                     love you america   1   NaN
# 163                             michelle wolf: nice lady   1   NaN
# 164                                              oseanne   1   NaN
# 165                                 my dinner with hervé   1   NaN
# 166                                the last man on earth   1   7.3
# 167                                            king lear   1   NaN
# 168                           dave chappelle: equanimity   1   NaN
# 169    super bowl lii halftime show starring justin t...   1   NaN
# 170         law & order true crime: the menendez murders   1   NaN
# 171                                               brexit   1   NaN
# 172                          adele live in new york city   1   NaN
#
#        Rotten_Tomatoes
# Index
# 0                  NaN
# 1                  9.3
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  9.7
# 6                  8.9
# 7                  8.1
# 8                  NaN
# 9                  9.6
# 10                 9.2
# 11                 NaN
# 12                 NaN
# 13                 9.7
# 14                 NaN
# 15                 9.1
# 16                 9.0
# 17                 NaN
# 18                 NaN
# 19                 9.6
# 20                 NaN
# 21                 9.6
# 22                 9.3
# 23                 7.8
# 24                 NaN
# 25                 NaN
# 26                 9.7
# 27                 9.6
# 28                 NaN
# 29                 NaN
# 30                 9.0
# 31                 8.1
# 32                10.0
# 33                 NaN
# 34                 NaN
# 35                 8.9
# 36                 9.1
# 37                 9.6
# 38                 NaN
# 39                 NaN
# 40                 8.3
# 41                 9.7
# 42                 8.5
# 43                 NaN
# 44                 NaN
# 45                10.0
# 46                 NaN
# 47                 8.6
# 48                 NaN
# 49                 NaN
# 50                 9.0
# 51                 9.3
# 52                 NaN
# 53                 9.6
# 54                 8.9
# 55                 NaN
# 56                 NaN
# 57                 NaN
# 58                 NaN
# 59                 NaN
# 60                 9.7
# 61                 NaN
# 62                 9.1
# 63                 NaN
# 64                 5.7
# 65                 7.8
# 66                 9.4
# 67                 9.5
# 68                 NaN
# 69                 NaN
# 70                 9.0
# 71                 9.2
# 72                 NaN
# 73                 9.7
# 74                 7.7
# 75                 9.4
# 76                 NaN
# 77                 9.6
# 78                 8.3
# 79                 9.4
# 80                 8.8
# 81                 8.8
# 82                 NaN
# 83                 9.7
# 84                 NaN
# 86                 8.5
# 87                 NaN
# 88                 NaN
# 89                 7.0
# 90                 NaN
# 91                 NaN
# 92                 9.3
# 93                 9.7
# 94                 NaN
# 95                 NaN
# 96                 8.8
# 97                 9.8
# 98                 NaN
# 99                 8.1
# 100                NaN
# 101                9.3
# 102                NaN
# 103                8.9
# 104                8.9
# 105                NaN
# 106                8.2
# 107                NaN
# 108                9.4
# 109                9.7
# 110                NaN
# 111                6.2
# 112                NaN
# 113                9.7
# 114                8.6
# 115                NaN
# 116                NaN
# 117                9.5
# 118                9.8
# 119                9.4
# 120                NaN
# 121                NaN
# 122                9.0
# 123                9.6
# 124                8.4
# 125                NaN
# 126                NaN
# 127                NaN
# 128                NaN
# 129                NaN
# 130                8.6
# 131                6.8
# 132                NaN
# 133                NaN
# 134                NaN
# 135                9.3
# 136                NaN
# 137                NaN
# 138                NaN
# 139                NaN
# 140                NaN
# 141                NaN
# 142                NaN
# 143                NaN
# 144                NaN
# 145                NaN
# 146                9.7
# 147                NaN
# 148                NaN
# 149                NaN
# 150                NaN
# 151                7.7
# 152                NaN
# 153                NaN
# 154                NaN
# 155                NaN
# 156                NaN
# 157                NaN
# 158                9.3
# 159                NaN
# 160                NaN
# 161                NaN
# 162                NaN
# 163                NaN
# 164                NaN
# 165                NaN
# 166                8.4
# 167                NaN
# 168                NaN
# 169                NaN
# 170                NaN
# 171                NaN
# 172                NaN
