# %%
import pandas as pd
from sqlalchemy import create_engine
import csv

# %%
tv_show_csv = "CSVs/tv_shows.csv"

tv_shows_df = pd.read_csv(tv_show_csv)

# %%
tv_shows_df
# Out:
#       Unnamed: 0                            Title  Year  Age  IMDb  \
# 0              0                     Breaking Bad  2008  18+   9.5
# 1              1                  Stranger Things  2016  16+   8.8
# 2              2                      Money Heist  2017  18+   8.4
# 3              3                         Sherlock  2010  16+   9.1
# 4              4                 Better Call Saul  2015  18+   8.7
# ...          ...                              ...   ...  ...   ...
# 5606        5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN
# 5607        5607                 Paradise Islands  2017  NaN   NaN
# 5608        5608                      Wild Russia  2018  NaN   NaN
# 5609        5609                      Love & Vets  2017  NaN   NaN
# 5610        5610         United States of Animals  2016  NaN   NaN
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# 0                96%        1     0            0        0     1
# ...

# %%
tv_shows_2019 = tv_shows_df.loc[tv_shows_df['Year'] == 2019]
tv_shows_2019
# Out:
#       Unnamed: 0                                        Title  Year  Age  \
# 21            21                                  The Witcher  2019  18+
# 41            41                             When They See Us  2019  18+
# 43            43                                   After Life  2019  18+
# 49            49                                   Dead to Me  2019  18+
# 56            56                                 Unbelievable  2019  18+
# ...          ...                                          ...   ...  ...
# 5590        5590                                   Fast Layne  2019  all
# 5595        5595                        Disney Family Sundays  2019  NaN
# 5597        5597  Buried Secrets of the Bible with Albert Lin  2019  NaN
# 5600        5600                            Prairie Dog Manor  2019  NaN
# 5604        5604                   Lost Treasures of the Maya  2019  NaN
#
#       IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# ...

# %%
tv_shows_2020 = tv_shows_df.loc[tv_shows_df['Year'] == 2020]
tv_shows_2020
# Out:
#       Unnamed: 0                                   Title  Year  Age  IMDb  \
# 46            46                       Never Have I Ever  2020  16+   8.0
# 50            50                              Unorthodox  2020  18+   8.1
# 62            62  Tiger King: Murder, Mayhem and Madness  2020  18+   7.8
# 95            95                 I Am Not Okay with This  2020  18+   7.6
# 101          101                             Outer Banks  2020  18+   7.6
# ...          ...                                     ...   ...  ...   ...
# 5562        5562                           Short Circuit  2020  all   NaN
# 5569        5569                       It's A Dog's Life  2020   7+   5.2
# 5576        5576                             Be our Chef  2020  all   6.9
# 5577        5577                              Shop Class  2020  all   7.2
# 5593        5593               Secrets of the Zoo: Tampa  2020  NaN   8.4
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# ...

# %%
tv_shows_df.sum(axis = 0)
# Out:
# Unnamed: 0                                              15738855
# Title          Breaking BadStranger ThingsMoney HeistSherlock...
# Year                                                    11283839
# IMDb                                                       31654
# Netflix                                                     1931
# Hulu                                                        1754
# Prime Video                                                 2144
# Disney+                                                      180
# type                                                        5611
# dtype: object

# %%
netflix_df = tv_shows_df.loc[tv_shows_df['Netflix'] == 1]
netflix_df
# Out:
#       Unnamed: 0                     Title  Year  Age  IMDb Rotten Tomatoes  \
# 0              0              Breaking Bad  2008  18+   9.5             96%
# 1              1           Stranger Things  2016  16+   8.8             93%
# 2              2               Money Heist  2017  18+   8.4             91%
# 3              3                  Sherlock  2010  16+   9.1             78%
# 4              4          Better Call Saul  2015  18+   8.7             97%
# ...          ...                       ...   ...  ...   ...             ...
# 1926        1926           The Golden Path  2012  NaN   NaN             NaN
# 1927        1927                JingleKids  2019  NaN   NaN             NaN
# 1928        1928  Sin Ellas No Hay Paraíso  2013  NaN   NaN             NaN
# 1929        1929         Slice of Paradise  2017  NaN   NaN             NaN
# 1930        1930               Two Fathers  2013  NaN   NaN             NaN
#
#       Netflix  Hulu  Prime Video  Disney+  type
# ...

# %%
hulu_df = tv_shows_df.loc[tv_shows_df['Hulu'] == 1]
hulu_df
# Out:
#       Unnamed: 0                             Title  Year  Age  IMDb  \
# 13            13                   Attack on Titan  2013  16+   8.8
# 15            15  Fullmetal Alchemist: Brotherhood  2009  18+   9.1
# 16            16                         Community  2009   7+   8.5
# 18            18              Parks and Recreation  2009  16+   8.6
# 22            22                        Twin Peaks  1990  18+   8.8
# ...          ...                               ...   ...  ...   ...
# 3561        3561                             Newsy  2016  NaN   NaN
# 3562        3562                      Modd Couples  2016  NaN   NaN
# 3563        3563                  Fantasy Forecast  2016  NaN   NaN
# 3564        3564             Secret Talent Theatre  2016  NaN   NaN
# 3565        3565      pocket.watch Challenge Squad  2018  NaN   NaN
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# 13               94%        1     1            0        0     1
# ...

# %%
prime_df = tv_shows_df.loc[tv_shows_df['Prime Video'] == 1]
prime_df
# Out:
#       Unnamed: 0                           Title  Year  Age  IMDb  \
# 18            18            Parks and Recreation  2009  16+   8.6
# 63            63  Star Trek: The Next Generation  1987   7+   8.6
# 71            71                   The Good Wife  2009  16+   8.3
# 77            77                  Schitt's Creek  2015  16+   8.4
# 88            88                     Burn Notice  2007   7+   7.9
# ...          ...                             ...   ...  ...   ...
# 5450        5450                 Sawyer Sessions  2015  NaN   NaN
# 5451        5451        Pinkfong! Dinosaur Songs  2014  NaN   NaN
# 5452        5452             How To Self-Publish  2017  NaN   NaN
# 5453        5453            BigDo2 - Random Hair  2016  NaN   NaN
# 5454        5454    We`ll Talk When You Get Back  2015  NaN   NaN
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# 18               93%        1     1            1        0     1
# ...

# %%
disney_df = tv_shows_df.loc[tv_shows_df['Disney+'] == 1]
disney_df
# Out:
#       Unnamed: 0                            Title  Year  Age  IMDb  \
# 472          472                         Lab Rats  2012   7+   6.6
# 516          516   America's Funniest Home Videos  1989   7+   6.2
# 563          563                      Brain Games  2011   7+   8.3
# 591          591                           Jessie  2011  all   5.9
# 846          846                         PJ Masks  2015  all   5.6
# ...          ...                              ...   ...  ...   ...
# 5606        5606  Tut's Treasures: Hidden Secrets  2018  NaN   NaN
# 5607        5607                 Paradise Islands  2017  NaN   NaN
# 5608        5608                      Wild Russia  2018  NaN   NaN
# 5609        5609                      Love & Vets  2017  NaN   NaN
# 5610        5610         United States of Animals  2016  NaN   NaN
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  type
# 472              NaN        1     0            0        1     1
# ...

# %%
tv_shows_final = tv_shows_df.rename({'Unnamed: 0':'Index'}, axis = 1 )
tv_shows_final.head()
# Out:
#    Index             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0      0      Breaking Bad  2008  18+   9.5             96%        1     0
# 1      1   Stranger Things  2016  16+   8.8             93%        1     0
# 2      2       Money Heist  2017  18+   8.4             91%        1     0
# 3      3          Sherlock  2010  16+   9.1             78%        1     0
# 4      4  Better Call Saul  2015  18+   8.7             97%        1     0
#
#    Prime Video  Disney+  type
# 0            0        0     1
# 1            0        0     1
# 2            0        0     1
# 3            0        0     1
# 4            0        0     1

# %%
#New CSV for importing to SQL server
tv_shows_final.to_csv('CSVs/final_csv.csv', index = False)

# %%
connection_string = "postgres:postgres@localhost:5432/project-2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
tv_shows_2020.to_sql(name='tv_shows', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
