# %%
import pandas as pd

# %%
df = pd.read_csv ('platforms_whole.csv')

# %%
df.head()
# Out:
#    id          show_title  show_year  imdb_rating  reel_rating  prime  \
# 0   1     Stranger Things       2016          8.7         96.0  False
# 1   2                Dark       2017          8.8         93.0  False
# 2   3  The Queen's Gambit       2020          8.6         93.0  False
# 3   4          Mindhunter       2017          8.6         91.0   True
# 4   5           The Crown       2016          8.7         91.0  False
#
#    netflix  disney   hulu
# 0     True   False  False
# 1     True   False  False
# 2     True   False  False
# 3     True   False  False
# 4     True   False  False

# %%
df["show_title"] = df["show_title"].str.lower()

# %%
df.head()
# Out:
#    id          show_title  show_year  imdb_rating  reel_rating  prime  \
# 0   1     stranger things       2016          8.7         96.0  False
# 1   2                dark       2017          8.8         93.0  False
# 2   3  the queen's gambit       2020          8.6         93.0  False
# 3   4          mindhunter       2017          8.6         91.0   True
# 4   5           the crown       2016          8.7         91.0  False
#
#    netflix  disney   hulu
# 0     True   False  False
# 1     True   False  False
# 2     True   False  False
# 3     True   False  False
# 4     True   False  False

# %%
df["show_title"] = df["show_title"].replace(',','', regex=True)

df.head()
# Out:
#    id          show_title  show_year  imdb_rating  reel_rating  prime  \
# 0   1     stranger things       2016          8.7         96.0  False
# 1   2                dark       2017          8.8         93.0  False
# 2   3  the queen's gambit       2020          8.6         93.0  False
# 3   4          mindhunter       2017          8.6         91.0   True
# 4   5           the crown       2016          8.7         91.0  False
#
#    netflix  disney   hulu
# 0     True   False  False
# 1     True   False  False
# 2     True   False  False
# 3     True   False  False
# 4     True   False  False

# %%
df.to_csv('platforms_whole_cleaned.csv', index=False)
